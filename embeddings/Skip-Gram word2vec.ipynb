# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

word_counts = Counter(int_words)

t = 1e-5
total_words = len(int_words)
frequency = { word : float(count) / total_words for word, count in word_counts.items() }
p_drop = {word : 1 - np.sqrt(float(t)/frequency[word]) for word in word_counts }
train_words = [w for w in int_words if p_drop[w] < random.random()] # The final subsampled word list

#print (len(train_words))
#print(train_words[:30])

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = random.randint (1, window_size)   # or window_size + 1?
    start = idx - R if idx >= R else 0
    end = idx + R + 1
    return list (set(words[start:idx] + words[idx+1:end]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder (tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder (tf.int32, shape=[None,None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200  # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable (tf.random_uniform ([n_vocab, n_embedding], -1.0, 1.0, dtype=tf.float32)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup (embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable (tf.truncated_normal ([n_vocab, n_embedding], stddev=0.1, dtype=tf.float32)) # create softmax weight matrix here
    softmax_b = tf.Variable (tf.zeros (n_vocab, dtype=tf.float32)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss (softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6620 0.2250 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6208 0.2276 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5000 0.2321 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5834 0.2289 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4853 0.2276 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5629 0.2268 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5741 0.2267 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5196 0.2259 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4774 0.2274 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4296 0.2276 sec/batch
# Nearest to time: undp, heroics, lenihan, fisa, hei, rbis, indicator, cells,
# Nearest to as: reich, lais, dniester, sert, cubans, daughters, macroeconomics, convention,
# Nearest to but: possesses, skate, eigenfunctions, implicated, stevie, lisp, lolita, owners,
# Nearest to states: guarneri, both, lis, conservative, instructions, silicon, chromatic, centimetre,
# Nearest to years: blueberry, advantages, sunnis, absorbed, iniquity, sensor, chauffeur, tedious,
# Nearest to this: caterpillar, rotation, stonemasons, ribozymes, incarnation, airflow, airs, explicit,
# Nearest to united: budgets, ifvs, psychomotor, writable, myrrh, nationally, resented, banat,
# Nearest to b: frisia, novelists, popularization, curve, diametrically, rcito, geq, trebuchet,
# Nearest to award: mandated, narmada, hesitant, hattusa, georgy, superhuman, beaumont, polo,
# Nearest to ice: buailte, kamchatka, appalachian, heel, cyp, consonant, positrons, approving,
# Nearest to pre: walker, shikai, sitter, piracy, printer, crocodile, meter, tinymux,
# Nearest to cost: jurassic, iota, spread, abusive, dilates, obrenovi, julien, thine,
# Nearest to issue: olympus, toulon, symbolise, hrer, blower, gibraltar, misogynist, appraisal,
# Nearest to ocean: sober, glenfinnan, sewerage, duplicated, wo, malformations, muzzle, orchids,
# Nearest to know: penitential, peachtree, feudalism, handguard, methadone, jurisprudence, siva, aldershot,
# Nearest to primarily: ulvaeus, theist, xbox, bella, eliminated, danuta, zam, grange,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4623 0.2302 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4156 0.2261 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3515 0.2264 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2516 0.2266 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1853 0.2253 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2059 0.2266 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1236 0.2280 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0904 0.2272 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0351 0.2273 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9955 0.2284 sec/batch
# Nearest to time: indicator, undp, cells, lineup, normalization, cubans, completed, headphones,
# Nearest to as: reich, has, cubans, convention, daughters, dniester, continues, lais,
# Nearest to but: possesses, owners, stevie, implicated, best, skate, bloc, victorious,
# Nearest to states: both, conservative, population, instructions, italy, guarneri, sixteen, paris,
# Nearest to years: advantages, absorbed, sensor, so, unit, blueberry, considered, thoroughly,
# Nearest to this: rotation, caterpillar, incarnation, explicit, ribozymes, emphasize, airflow, hong,
# Nearest to united: nationally, budgets, expansion, ifvs, myrrh, writable, battalion, psychomotor,
# Nearest to b: frisia, popularization, curve, novelists, rcito, became, geq, diametrically,
# Nearest to award: mandated, hesitant, increased, narmada, superhuman, traced, beaumont, hattusa,
# Nearest to ice: kamchatka, buailte, cyp, sda, broch, nodes, appalachian, intellectual,
# Nearest to pre: walker, meter, development, sqrt, printer, crocodile, symbolize, sitter,
# Nearest to cost: spread, jurassic, julien, abusive, fuels, dilates, iota, membership,
# Nearest to issue: olympus, hrer, toulon, symbolise, appraisal, publicity, gibraltar, zog,
# Nearest to ocean: sober, duplicated, gradually, sketches, enriched, machines, muzzle, wo,
# Nearest to know: peachtree, penitential, jurisprudence, service, feudalism, methadone, ivory, resurrected,
# Nearest to primarily: bella, eliminated, xbox, usefulness, morale, machine, graduating, mailing,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9688 0.2313 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9199 0.2281 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8799 0.2283 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8793 0.2286 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8052 0.2273 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8221 0.2286 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8081 0.2277 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7720 0.2285 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7679 0.2305 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7849 0.2314 sec/batch
# Nearest to time: indicator, undp, reconstruction, cells, lineup, fisa, normalization, eck,
# Nearest to as: reich, cubans, daughters, has, sert, convention, dniester, thinkers,
# Nearest to but: possesses, owners, implicated, bloc, victorious, stevie, skate, eigenfunctions,
# Nearest to states: both, italy, conservative, population, tough, acknowledges, lis, paris,
# Nearest to years: advantages, expectancy, absorbed, blueberry, tedious, sensor, thoroughly, iniquity,
# Nearest to this: rotation, caterpillar, incarnation, airflow, explicit, plato, paradox, ribozymes,
# Nearest to united: budgets, nationally, allied, seats, writable, ifvs, cia, unifying,
# Nearest to b: novelists, popularization, frisia, curve, britain, rcito, diametrically, became,
# Nearest to award: mandated, hesitant, increased, beaumont, traced, polo, superhuman, narmada,
# Nearest to ice: kamchatka, strange, nodes, intellectual, cyrus, cyp, chaplain, sda,
# Nearest to pre: meter, walker, piracy, crocodile, symbolize, development, sqrt, printer,
# Nearest to cost: jurassic, spread, julien, abusive, fuels, membership, iota, dilates,
# Nearest to issue: olympus, gibraltar, symbolise, toulon, hrer, appraisal, publicity, liberty,
# Nearest to ocean: duplicated, sober, muzzle, sketches, countess, gradually, sealing, intelsat,
# Nearest to know: peachtree, holocaust, penitential, jurisprudence, feudalism, ivory, siva, shipments,
# Nearest to primarily: bella, eliminated, graduating, mailing, xbox, morale, machine, austerlitz,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7953 0.2315 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7699 0.2316 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7326 0.2289 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7174 0.2280 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7420 0.2294 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6799 0.2290 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7099 0.2300 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7130 0.2296 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7193 0.2297 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6568 0.2297 sec/batch
# Nearest to time: undp, indicator, eck, hei, reconstruction, lineup, fisa, specificity,
# Nearest to as: reich, has, cubans, daughters, thinkers, sert, lais, dniester,
# Nearest to but: possesses, victorious, implicated, bloc, lolita, lisp, owners, skate,
# Nearest to states: italy, both, chromatic, conservative, population, acknowledges, lis, malay,
# Nearest to years: expectancy, iniquity, absorbed, blueberry, tedious, sunnis, surmise, icrc,
# Nearest to this: rotation, airflow, caterpillar, incarnation, explicit, plato, paradox, departmental,
# Nearest to united: budgets, allied, nationally, seats, cia, ifvs, battalion, landsat,
# Nearest to b: novelists, popularization, frisia, curve, afonso, geq, salford, britain,
# Nearest to award: mandated, beaumont, increased, hesitant, polo, georgy, conscience, wace,
# Nearest to ice: kamchatka, cyp, strange, nodes, chaplain, cyrus, heel, intellectual,
# Nearest to pre: piracy, meter, crocodile, walker, symbolize, sitter, printer, development,
# Nearest to cost: jurassic, abusive, julien, iota, spread, fuels, dilates, mega,
# Nearest to issue: olympus, toulon, symbolise, gibraltar, hrer, blower, liberty, appraisal,
# Nearest to ocean: duplicated, intelsat, sober, sewerage, countess, muzzle, leonard, orchids,
# Nearest to know: peachtree, holocaust, siva, feudalism, jurisprudence, penitential, handguard, lutenist,
# Nearest to primarily: bella, eliminated, graduating, airship, mailing, morale, austerlitz, birmingham,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6480 0.2308 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6625 0.2300 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6188 0.2298 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6234 0.2306 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6082 0.2288 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6394 0.2301 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5792 0.1728 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5546 0.2324 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5015 0.2301 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4909 0.2303 sec/batch
# Nearest to time: indicator, undp, reconstruction, eck, specificity, lenihan, jeffery, lineup,
# Nearest to as: reich, has, sert, thinkers, cubans, daughters, lais, dniester,
# Nearest to but: wisely, possesses, wailing, owners, victorious, counterterrorism, implicated, lolita,
# Nearest to states: italy, both, malay, paris, population, conservative, chromatic, sahara,
# Nearest to years: expectancy, iniquity, blueberry, sunnis, surmise, birth, absorbed, icrc,
# Nearest to this: rotation, airflow, explicit, incarnation, paradox, departmental, caterpillar, druid,
# Nearest to united: allied, budgets, cia, nationally, seats, ifvs, landsat, writable,
# Nearest to b: novelists, afonso, laureate, popularization, frisia, footballer, bourbon, edward,
# Nearest to award: mandated, beaumont, georgy, nebraska, polo, mcdaniel, increased, conscience,
# Nearest to ice: kamchatka, cyp, musicology, encountering, strange, chaplain, cyrus, nodes,
# Nearest to pre: piracy, crocodile, meter, symbolize, sitter, walker, development, threatens,
# Nearest to cost: jurassic, abusive, julien, iota, fuels, spread, safavid, plastic,
# Nearest to issue: olympus, symbolise, toulon, gibraltar, hrer, misogynist, blower, liberty,
# Nearest to ocean: intelsat, duplicated, north, urals, sewerage, muzzle, paternalistic, coastline,
# Nearest to know: siva, peachtree, handguard, lutenist, holocaust, feudalism, penitential, shipments,
# Nearest to primarily: bella, eliminated, mailing, austerlitz, airship, theist, morale, xxix,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5212 0.2321 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4788 0.2298 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4518 0.2289 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5414 0.2301 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4866 0.2295 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4845 0.2307 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4793 0.2303 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4075 0.2315 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4134 0.2329 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4309 0.2311 sec/batch
# Nearest to time: indicator, undp, eck, stagnated, specificity, lenihan, lineup, jeffery,
# Nearest to as: has, sert, reich, cubans, thinkers, dniester, lais, macroeconomics,
# Nearest to but: wailing, possesses, wisely, counterterrorism, victorious, owners, rst, poststructuralist,
# Nearest to states: italy, malay, both, population, chromatic, countries, joint, conservative,
# Nearest to years: expectancy, birth, iniquity, migrant, age, population, sunnis, blueberry,
# Nearest to this: rotation, airflow, incarnation, explicit, paradox, departmental, caterpillar, inequality,
# Nearest to united: allied, cia, budgets, seats, nationally, ifvs, landsat, yuletide,
# Nearest to b: novelists, geq, popularization, curve, frisia, salford, bourbon, edward,
# Nearest to award: mandated, nebraska, beaumont, mcdaniel, georgy, twickenham, polo, mss,
# Nearest to ice: kamchatka, cyp, musicology, chaplain, nodes, encountering, strange, cyrus,
# Nearest to pre: piracy, crocodile, sitter, meter, symbolize, threatens, development, hass,
# Nearest to cost: jurassic, fuels, abusive, julien, plastic, iota, mega, limiting,
# Nearest to issue: olympus, toulon, symbolise, liberty, blower, hrer, tolerated, gibraltar,
# Nearest to ocean: intelsat, north, coastline, duplicated, urals, approximately, orchids, atlantic,
# Nearest to know: siva, lutenist, handguard, peachtree, sommers, holocaust, feudalism, resurrected,
# Nearest to primarily: mailing, xxix, austerlitz, eliminated, usefulness, airship, stuffy, bella,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4441 0.2325 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4227 0.2307 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4448 0.2315 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4017 0.2297 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3932 0.2291 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4241 0.2301 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3684 0.2306 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3893 0.2302 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4177 0.2300 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3799 0.2334 sec/batch
# Nearest to time: indicator, eck, lenihan, stagnated, fisa, undp, lineup, jeffery,
# Nearest to as: has, sert, reich, cubans, macroeconomics, lais, dniester, thinkers,
# Nearest to but: victorious, wisely, possesses, owners, wailing, poststructuralist, bloc, skate,
# Nearest to states: italy, malay, both, joint, population, occupation, countries, relations,
# Nearest to years: expectancy, birth, age, iniquity, males, population, sunnis, migrant,
# Nearest to this: rotation, airflow, incarnation, explicit, paradox, inequality, caterpillar, stonemasons,
# Nearest to united: allied, budgets, cia, seats, landsat, ifvs, tampa, nationally,
# Nearest to b: novelists, geq, curve, edward, popularization, salford, afonso, y,
# Nearest to award: mandated, mcdaniel, beaumont, nebraska, georgy, medal, twickenham, polo,
# Nearest to ice: kamchatka, cyp, musicology, cyrus, strange, chaplain, appalachian, organisers,
# Nearest to pre: piracy, crocodile, sitter, meter, symbolize, development, threatens, hass,
# Nearest to cost: jurassic, fuels, abusive, plastic, elbow, julien, limiting, mega,
# Nearest to issue: blower, symbolise, olympus, liberty, toulon, tolerated, wolfe, directx,
# Nearest to ocean: intelsat, coastline, north, atlantic, approximately, urals, southwestern, orchids,
# Nearest to know: siva, lutenist, handguard, sommers, peachtree, vehemently, penitential, aldershot,
# Nearest to primarily: eliminated, ayyavazhi, xxix, mailing, usefulness, austerlitz, stuffy, airship,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3751 0.2338 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3916 0.2318 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3518 0.2310 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3779 0.2326 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3898 0.2317 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3338 0.2314 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3730 0.2311 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3893 0.2301 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3220 0.2319 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3251 0.2294 sec/batch
# Nearest to time: indicator, stagnated, lenihan, eck, fisa, undp, jeffery, logically,
# Nearest to as: has, sert, macroeconomics, cubans, reich, thinkers, group, dniester,
# Nearest to but: wisely, victorious, possesses, bloc, wailing, poststructuralist, skate, complain,
# Nearest to states: italy, both, malay, occupation, joint, relations, countries, mohamad,
# Nearest to years: birth, expectancy, age, iniquity, population, overshadowing, migration, migrant,
# Nearest to this: rotation, airflow, explicit, disintegrates, suras, incarnation, inequality, stonemasons,
# Nearest to united: budgets, cia, allied, seats, ifvs, governmental, landsat, tampa,
# Nearest to b: novelists, geq, curve, y, popularization, edward, salford, tol,
# Nearest to award: mandated, mcdaniel, medal, nebraska, polo, beaumont, laureates, twickenham,
# Nearest to ice: kamchatka, musicology, cyp, organisers, offseason, cyrus, heel, chaplain,
# Nearest to pre: piracy, crocodile, sitter, meter, symbolize, development, threatens, hass,
# Nearest to cost: fuels, jurassic, abusive, plastic, mega, elbow, julien, automated,
# Nearest to issue: symbolise, blower, liberty, olympus, tolerated, toulon, directx, unanimously,
# Nearest to ocean: intelsat, coastline, atlantic, urals, north, sewerage, southwestern, kilometers,
# Nearest to know: siva, lutenist, handguard, sommers, discipleship, vehemently, peachtree, resurrected,
# Nearest to primarily: ayyavazhi, eliminated, xxix, mailing, mens, usefulness, stuffy, subservient,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3532 0.2337 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2706 0.2329 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3739 0.2320 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3596 0.2321 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4026 0.2310 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2709 0.2318 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3306 0.2296 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3619 0.2314 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2397 0.2309 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2820 0.2309 sec/batch
# Nearest to time: indicator, stagnated, lenihan, undp, eck, logically, last, jeffery,
# Nearest to as: has, sert, macroeconomics, cubans, thinkers, dniester, group, loins,
# Nearest to but: wisely, possesses, victorious, poststructuralist, bloc, wailing, infertile, ampex,
# Nearest to states: malay, both, italy, joint, mohamad, designated, traore, sahara,
# Nearest to years: birth, expectancy, age, migrant, population, migration, iniquity, males,
# Nearest to this: rotation, airflow, explicit, incarnation, stonemasons, suras, inequality, gluten,
# Nearest to united: budgets, cia, tampa, allied, ifvs, seats, landsat, midway,
# Nearest to b: geq, edward, marquess, laureate, kaye, novelists, d, footballer,
# Nearest to award: mandated, mcdaniel, medal, futurama, laureates, petrarca, polo, best,
# Nearest to ice: kamchatka, musicology, cyp, offseason, encountering, appalachian, cyrus, organisers,
# Nearest to pre: piracy, crocodile, sitter, symbolize, development, meter, knower, ezek,
# Nearest to cost: fuels, jurassic, abusive, automated, mainframe, receipts, mega, targets,
# Nearest to issue: liberty, symbolise, blower, toulon, olympus, unanimously, tolerated, directx,
# Nearest to ocean: intelsat, coastline, atlantic, urals, north, sewerage, bahamas, reefs,
# Nearest to know: siva, lutenist, handguard, sommers, discipleship, peachtree, supervillain, aldershot,
# Nearest to primarily: ayyavazhi, eliminated, mens, mailing, stuffy, xxix, morale, usefulness,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2944 0.2352 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2788 0.2307 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3231 0.1186 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2342 0.2336 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2350 0.2325 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2104 0.2327 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2214 0.2314 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1972 0.2337 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2204 0.2317 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1877 0.2332 sec/batch
# Nearest to time: indicator, stagnated, last, undp, particle, eck, lenihan, elegantly,
# Nearest to as: has, sert, macroeconomics, cubans, dniester, group, thinkers, loins,
# Nearest to but: victorious, possesses, wisely, poststructuralist, bloc, wailing, canopic, insensitive,
# Nearest to states: malay, both, italy, joint, abodes, landlords, traore, legislature,
# Nearest to years: birth, expectancy, age, migrant, males, sunnis, iniquity, migration,
# Nearest to this: rotation, airflow, gluten, suras, inequality, stonemasons, incarnation, explicit,
# Nearest to united: budgets, cia, tampa, landsat, seats, ifvs, engage, emden,
# Nearest to b: geq, curve, popularization, frisia, marquess, edward, tr, laureate,
# Nearest to award: medal, mandated, best, mcdaniel, futurama, nominated, peebles, polo,
# Nearest to ice: kamchatka, musicology, cyp, appalachian, rebuilt, offseason, encountering, houses,
# Nearest to pre: piracy, crocodile, sitter, meter, symbolize, development, knower, hass,
# Nearest to cost: fuels, jurassic, mega, targets, elbow, receipts, abusive, automated,
# Nearest to issue: blower, liberty, symbolise, tolerated, toulon, unanimously, directx, irregularities,
# Nearest to ocean: intelsat, atlantic, urals, coastline, sewerage, isps, reefs, north,
# Nearest to know: siva, lutenist, handguard, sommers, discipleship, supervillain, aldershot, bringer,
# Nearest to primarily: ayyavazhi, mens, stuffy, eliminated, morale, xxix, subservient, mailing,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2730 0.2344 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2169 0.2336 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2177 0.2322 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1599 0.2331 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1866 0.2324 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1797 0.2326 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1531 0.2361 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1708 0.2368 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1963 0.2331 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1814 0.2329 sec/batch
# Nearest to time: indicator, logically, particle, last, stagnated, elegantly, eck, lenihan,
# Nearest to as: has, macroeconomics, sert, dniester, convention, loins, cubans, thinkers,
# Nearest to but: victorious, possesses, wisely, bloc, poststructuralist, sharp, canopic, liliales,
# Nearest to states: both, malay, joint, italy, abodes, relations, assurance, traore,
# Nearest to years: birth, expectancy, age, males, migrant, iniquity, population, sunnis,
# Nearest to this: rotation, airflow, gluten, inequality, incarnation, judged, stonemasons, departmental,
# Nearest to united: budgets, cia, tampa, emden, aimed, engage, landsat, midway,
# Nearest to b: geq, curve, y, popularization, subgroup, tol, frisia, tr,
# Nearest to award: medal, best, mandated, nominated, futurama, mcdaniel, laureates, peebles,
# Nearest to ice: kamchatka, musicology, cyp, appalachian, rebuilt, windy, organisers, steep,
# Nearest to pre: piracy, sitter, crocodile, development, meter, symbolize, hass, threatens,
# Nearest to cost: fuels, jurassic, elbow, shop, receipts, mega, targets, costs,
# Nearest to issue: blower, liberty, tolerated, symbolise, unanimously, irregularities, directx, toulon,
# Nearest to ocean: intelsat, atlantic, reefs, urals, trench, sewerage, isps, coastline,
# Nearest to know: lutenist, handguard, siva, discipleship, sommers, supervillain, priori, bringer,
# Nearest to primarily: ayyavazhi, stuffy, detected, mens, usefulness, subservient, wooden, meats,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.2018 0.2338 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2374 0.2320 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1607 0.2346 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1301 0.2324 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2178 0.2309 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2012 0.2315 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2005 0.2316 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1340 0.2309 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1669 0.2311 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1616 0.2308 sec/batch
# Nearest to time: indicator, logically, particle, last, stagnated, heroics, eck, elegantly,
# Nearest to as: has, macroeconomics, sert, retraced, horeb, important, dniester, duchesse,
# Nearest to but: victorious, poststructuralist, possesses, wisely, canopic, bloc, tolls, liliales,
# Nearest to states: malay, italy, both, geneva, relations, joint, abodes, traore,
# Nearest to years: birth, expectancy, age, population, migrant, males, migration, male,
# Nearest to this: rotation, airflow, incarnation, judged, gluten, paradox, inequality, emphasize,
# Nearest to united: budgets, cia, emden, tampa, landsat, governmental, agency, midway,
# Nearest to b: geq, curve, y, subgroup, popularization, tol, tr, marquess,
# Nearest to award: medal, best, mandated, futurama, nominated, mcdaniel, laureates, petrarca,
# Nearest to ice: kamchatka, appalachian, musicology, rebuilt, cyp, windy, steep, organisers,
# Nearest to pre: piracy, sitter, crocodile, meter, development, symbolize, threatens, hass,
# Nearest to cost: fuels, jurassic, transaction, receipts, elbow, targets, spread, mega,
# Nearest to issue: liberty, tolerated, unanimously, blower, irregularities, directx, toulon, symbolise,
# Nearest to ocean: intelsat, atlantic, urals, reefs, trench, isps, coastline, sewerage,
# Nearest to know: handguard, lutenist, discipleship, sommers, siva, supervillain, bringer, gwat,
# Nearest to primarily: ayyavazhi, subservient, stuffy, mens, wooden, morale, intercity, eliminated,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2224 0.2328 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1693 0.2340 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1726 0.2323 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2006 0.2325 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1620 0.2351 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1436 0.2301 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1766 0.2329 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0833 0.2323 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1921 0.2320 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2079 0.2331 sec/batch
# Nearest to time: indicator, last, logically, heroics, eck, particle, stagnated, lucky,
# Nearest to as: has, macroeconomics, walesa, sert, dniester, duchesse, retraced, hellespont,
# Nearest to but: victorious, bloc, wisely, canopic, enchiridion, possesses, poststructuralist, clan,
# Nearest to states: geneva, italy, both, malay, legislature, joint, abodes, announce,
# Nearest to years: birth, age, expectancy, population, males, sunnis, zero, iniquity,
# Nearest to this: judged, rotation, incarnation, suras, quarrelled, departmental, inequality, disintegrates,
# Nearest to united: budgets, cia, emden, tampa, landsat, governmental, harrison, agency,
# Nearest to b: geq, laureate, marquess, edward, kaye, curve, tr, popularization,
# Nearest to award: medal, best, mandated, nominated, futurama, mcdaniel, peebles, petrarca,
# Nearest to ice: kamchatka, appalachian, musicology, rosy, rebuilt, cyp, shrek, organisers,
# Nearest to pre: piracy, sitter, development, meter, crocodile, symbolize, threatens, hass,
# Nearest to cost: transaction, fuels, mega, jurassic, shop, elbow, mainframe, targets,
# Nearest to issue: irregularities, liberty, unanimously, tolerated, directx, blower, toulon, symbolise,
# Nearest to ocean: intelsat, urals, atlantic, reefs, coastline, sewerage, trench, radios,
# Nearest to know: handguard, lutenist, discipleship, supervillain, siva, bringer, sommers, conjugative,
# Nearest to primarily: ayyavazhi, subservient, mens, lutheranism, stuffy, detected, oes, usefulness,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2423 0.2350 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1542 0.2323 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1274 0.2322 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1708 0.2304 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0127 0.2344 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1676 0.2323 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1587 0.2323 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1361 0.2304 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1825 0.0584 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0950 0.2321 sec/batch
# Nearest to time: indicator, last, stagnated, logically, particle, heroics, lucky, undp,
# Nearest to as: has, macroeconomics, sert, mandatory, hissarlik, retraced, horeb, important,
# Nearest to but: victorious, wisely, canopic, bloc, poststructuralist, infertile, possesses, wasteful,
# Nearest to states: geneva, both, malay, abodes, italy, legislature, announce, joint,
# Nearest to years: birth, age, expectancy, population, zero, migration, migrant, male,
# Nearest to this: rotation, airflow, gluten, suras, departmental, incarnation, disintegrates, judged,
# Nearest to united: budgets, tampa, cia, emden, landsat, governmental, agency, yuletide,
# Nearest to b: geq, curve, laureate, popularization, tr, marquess, edward, tol,
# Nearest to award: best, medal, nominated, futurama, mandated, mcdaniel, awards, bittersweet,
# Nearest to ice: kamchatka, appalachian, musicology, cyp, rebuilt, rosy, shrek, organisers,
# Nearest to pre: piracy, sitter, development, symbolize, meter, threatens, crocodile, hass,
# Nearest to cost: transaction, mainframe, mega, fuels, receipts, elbow, shop, costs,
# Nearest to issue: irregularities, tolerated, unanimously, directx, blower, toulon, appraisal, liberty,
# Nearest to ocean: intelsat, urals, atlantic, trench, arabsat, sewerage, reefs, coastline,
# Nearest to know: handguard, lutenist, discipleship, supervillain, sommers, conjugative, siva, priori,
# Nearest to primarily: ayyavazhi, lutheranism, subservient, oes, stuffy, mens, comprises, morale,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0614 0.2351 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0698 0.2321 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0633 0.2318 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0478 0.2320 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0805 0.2333 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0705 0.2328 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0754 0.2314 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0966 0.2339 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1282 0.2345 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9988 0.2318 sec/batch
# Nearest to time: indicator, logically, last, stagnated, particle, elegantly, helices, lucky,
# Nearest to as: has, macroeconomics, sert, hissarlik, important, retraced, azad, vivacious,
# Nearest to but: victorious, infertile, canopic, possesses, sharp, wasteful, arrival, wisely,
# Nearest to states: both, geneva, announce, malay, joint, italy, relations, legislature,
# Nearest to years: birth, age, expectancy, population, zero, migration, sunnis, males,
# Nearest to this: rotation, airflow, judged, gluten, suras, incarnation, stonemasons, inequality,
# Nearest to united: budgets, cia, emden, tampa, engage, landsat, governmental, aimed,
# Nearest to b: geq, curve, popularization, tol, subgroup, minoru, y, putting,
# Nearest to award: best, medal, nominated, mandated, awards, futurama, peebles, bittersweet,
# Nearest to ice: kamchatka, appalachian, musicology, cyp, rebuilt, rosy, shrek, grosso,
# Nearest to pre: piracy, development, sitter, symbolize, meter, crocodile, threatens, hass,
# Nearest to cost: transaction, shop, mega, receipts, fuels, mainframe, elbow, costs,
# Nearest to issue: tolerated, directx, blower, irregularities, appraisal, unanimously, toulon, resolve,
# Nearest to ocean: intelsat, atlantic, urals, arabsat, sewerage, reefs, trench, isps,
# Nearest to know: lutenist, handguard, discipleship, i, supervillain, sommers, conjugative, if,
# Nearest to primarily: ayyavazhi, oes, subservient, morale, iru, mens, detected, stuffy,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0141 0.2344 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0351 0.2323 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0505 0.2317 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0448 0.2318 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0807 0.2322 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0657 0.2328 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0645 0.2316 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1269 0.2339 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0222 0.2320 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0507 0.2310 sec/batch
# Nearest to time: indicator, logically, last, particle, heroics, elegantly, stagnated, helices,
# Nearest to as: has, macroeconomics, important, sert, hissarlik, amorite, mandatory, walesa,
# Nearest to but: victorious, possesses, infertile, noumena, poststructuralist, canopic, significant, enchiridion,
# Nearest to states: geneva, both, italy, joint, malay, anfa, announce, abodes,
# Nearest to years: birth, age, expectancy, population, zero, males, migration, male,
# Nearest to this: rotation, airflow, gluten, judged, incarnation, suras, inequality, emphasize,
# Nearest to united: budgets, emden, tampa, cia, governmental, engage, midway, landsat,
# Nearest to b: geq, curve, subgroup, popularization, tol, minoru, y, laureate,
# Nearest to award: best, medal, nominated, awards, mandated, futurama, peebles, bittersweet,
# Nearest to ice: kamchatka, appalachian, musicology, cyp, shrek, offseason, rosy, rebuilt,
# Nearest to pre: piracy, sitter, development, threatens, symbolize, crocodile, meter, hass,
# Nearest to cost: shop, fuels, transaction, receipts, spread, mega, costs, mainframe,
# Nearest to issue: blower, tolerated, irregularities, appraisal, resolve, directx, unanimously, smarter,
# Nearest to ocean: intelsat, atlantic, urals, arabsat, trench, reefs, sewerage, relay,
# Nearest to know: i, discipleship, handguard, lutenist, supervillain, sommers, if, bringer,
# Nearest to primarily: ayyavazhi, oes, iru, mens, lutheranism, subservient, oesophagus, stuffy,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0711 0.2353 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0729 0.2344 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0687 0.2327 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0680 0.2326 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0542 0.2324 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0490 0.2328 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0293 0.2321 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0532 0.2347 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0814 0.2326 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0516 0.2324 sec/batch
# Nearest to time: indicator, logically, last, particle, stagnated, so, heroics, lucky,
# Nearest to as: has, macroeconomics, walesa, sert, important, mandatory, hissarlik, vivacious,
# Nearest to but: victorious, possesses, canopic, enchiridion, significant, wisely, quantity, infertile,
# Nearest to states: both, geneva, malay, announce, abodes, italy, anfa, joint,
# Nearest to years: birth, age, expectancy, population, zero, sunnis, migration, iniquity,
# Nearest to this: airflow, rotation, gluten, incarnation, judged, suras, inequality, quarrelled,
# Nearest to united: budgets, emden, tampa, governmental, engage, cia, harrison, juilliard,
# Nearest to b: geq, curve, subgroup, tol, popularization, minoru, y, laureate,
# Nearest to award: best, medal, awards, mandated, nominated, futurama, peebles, hugo,
# Nearest to ice: kamchatka, appalachian, musicology, cyp, rosy, organisers, shrek, positrons,
# Nearest to pre: piracy, development, sitter, threatens, symbolize, meter, hass, became,
# Nearest to cost: fuels, transaction, mega, receipts, screws, mainframe, spread, shop,
# Nearest to issue: appraisal, irregularities, resolve, unanimously, blower, tolerated, directx, gibraltar,
# Nearest to ocean: intelsat, atlantic, arabsat, sewerage, urals, reefs, trench, relay,
# Nearest to know: i, discipleship, handguard, lutenist, supervillain, if, sommers, conjugative,
# Nearest to primarily: oes, iru, ayyavazhi, mahavira, mens, bella, detected, lutheranism,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0655 0.2343 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9919 0.2328 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0227 0.2314 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0548 0.2357 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0737 0.2344 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1044 0.2342 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1313 0.2350 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0380 0.2346 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0253 0.2318 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0638 0.2311 sec/batch
# Nearest to time: indicator, logically, stagnated, particle, last, helices, heroics, so,
# Nearest to as: has, macroeconomics, sert, walesa, mandatory, yochanan, be, hissarlik,
# Nearest to but: victorious, canopic, possesses, lisp, bloc, enchiridion, trotskyism, indulgences,
# Nearest to states: both, geneva, announce, united, abodes, italy, malay, anfa,
# Nearest to years: age, birth, expectancy, population, zero, males, sunnis, migration,
# Nearest to this: rotation, gluten, airflow, judged, incarnation, suras, disintegrates, inequality,
# Nearest to united: budgets, emden, harrison, states, tampa, governmental, engage, juilliard,
# Nearest to b: geq, curve, popularization, minoru, subgroup, tol, laureate, edward,
# Nearest to award: best, medal, awards, nominated, mandated, futurama, peebles, bittersweet,
# Nearest to ice: kamchatka, appalachian, musicology, organisers, shrek, offseason, rosy, anisotropic,
# Nearest to pre: piracy, sitter, development, threatens, symbolize, meter, crocodile, resistors,
# Nearest to cost: shop, transaction, receipts, costs, fuels, mega, spread, mainframe,
# Nearest to issue: appraisal, unanimously, resolve, irregularities, directx, toulon, tolerated, blower,
# Nearest to ocean: intelsat, atlantic, arabsat, reefs, urals, sewerage, mariana, trench,
# Nearest to know: i, discipleship, disposable, supervillain, if, sommers, lutenist, conjugative,
# Nearest to primarily: mens, ayyavazhi, oes, lutheranism, iru, bella, mahavira, comprises,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9439 0.2363 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0151 0.2342 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0362 0.2331 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0326 0.2344 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0665 0.2344 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0373 0.2328 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0092 0.2360 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9800 0.2344 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0187 0.2329 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9415 0.2314 sec/batch
# Nearest to time: indicator, logically, last, stagnated, particle, heroics, helices, lucky,
# Nearest to as: has, sert, panzers, walesa, yochanan, vivacious, macroeconomics, hissarlik,
# Nearest to but: victorious, canopic, possesses, lisp, confuses, infertile, quantity, mandriva,
# Nearest to states: announce, both, united, geneva, cubicle, anfa, abodes, malay,
# Nearest to years: age, birth, expectancy, population, zero, sunnis, males, male,
# Nearest to this: rotation, gluten, incarnation, airflow, suras, judged, the, paradox,
# Nearest to united: budgets, emden, states, tampa, engage, harrison, taya, governmental,
# Nearest to b: geq, curve, laureate, minoru, popularization, edward, tol, subgroup,
# Nearest to award: best, medal, awards, nominated, mandated, nominations, peebles, futurama,
# Nearest to ice: kamchatka, appalachian, organisers, musicology, anisotropic, shrek, cyp, positrons,
# Nearest to pre: piracy, sitter, development, symbolize, threatens, hass, meter, crocodile,
# Nearest to cost: shop, mega, screws, costs, transaction, receipts, mainframe, newark,
# Nearest to issue: appraisal, unanimously, directx, irregularities, resolve, blower, toulon, tolerated,
# Nearest to ocean: intelsat, atlantic, arabsat, urals, sewerage, reefs, trench, mariana,
# Nearest to know: i, discipleship, if, never, conjugative, disposable, supervillain, lutenist,
# Nearest to primarily: ayyavazhi, oes, lutheranism, iru, mens, comprises, mahavira, austerlitz,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9630 0.2370 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9723 0.2346 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0281 0.2329 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0108 0.2352 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0229 0.2333 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0013 0.2336 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9370 0.2355 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9701 0.2367 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9101 0.2333 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9772 0.2354 sec/batch
# Nearest to time: indicator, logically, last, stagnated, particle, helices, heroics, so,
# Nearest to as: has, azad, macroeconomics, important, sert, be, mandatory, hissarlik,
# Nearest to but: victorious, infertile, canopic, possesses, arrival, berries, mandriva, wasteful,
# Nearest to states: united, both, malay, announce, geneva, cubicle, usgs, anfa,
# Nearest to years: age, birth, expectancy, zero, population, males, five, male,
# Nearest to this: rotation, judged, gluten, incarnation, inequality, airflow, suras, the,
# Nearest to united: states, emden, engage, budgets, canada, supranational, governmental, autodidacts,
# Nearest to b: geq, curve, popularization, minoru, subgroup, tol, putting, generalizations,
# Nearest to award: best, medal, awards, nominated, nominations, mandated, peebles, futurama,
# Nearest to ice: kamchatka, appalachian, organisers, cyp, endothermic, anisotropic, shrek, musicology,
# Nearest to pre: piracy, development, sitter, symbolize, threatens, meter, hass, crocodile,
# Nearest to cost: shop, screws, mega, newark, receipts, spread, liberalized, costs,
# Nearest to issue: appraisal, unanimously, resolve, tolerated, directx, irregularities, blower, toulon,
# Nearest to ocean: intelsat, atlantic, arabsat, urals, sewerage, reefs, mariana, relay,
# Nearest to know: i, if, discipleship, conjugative, sommers, disposable, me, lutenist,
# Nearest to primarily: oes, lutheranism, ayyavazhi, iru, detected, mens, mahavira, comprises,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0132 0.2359 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9954 0.2340 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9895 0.2352 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9957 0.2368 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0565 0.2337 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9827 0.2338 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9679 0.2344 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0129 0.1766 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9692 0.2350 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0172 0.2335 sec/batch
# Nearest to time: indicator, logically, last, stagnated, heroics, memory, helices, particle,
# Nearest to as: has, macroeconomics, important, azad, walesa, sert, mandatory, panzers,
# Nearest to but: victorious, infertile, canopic, noumena, possesses, enchiridion, mandriva, lisp,
# Nearest to states: united, both, announce, geneva, italy, malay, anfa, cubicle,
# Nearest to years: age, birth, expectancy, population, males, zero, older, male,
# Nearest to this: rotation, incarnation, judged, gluten, airflow, suras, inequality, the,
# Nearest to united: states, emden, budgets, tampa, engage, mckinley, harrison, canada,
# Nearest to b: geq, curve, minoru, laureate, popularization, subgroup, tol, edward,
# Nearest to award: best, medal, awards, nominated, mandated, in, nominations, prizes,
# Nearest to ice: kamchatka, appalachian, organisers, shrek, endothermic, musicology, broch, anisotropic,
# Nearest to pre: piracy, development, sitter, symbolize, threatens, meter, greatly, holyrood,
# Nearest to cost: screws, spread, shop, costs, fuels, mega, mainframe, receipts,
# Nearest to issue: appraisal, resolve, tolerated, unanimously, irregularities, toulon, directx, blower,
# Nearest to ocean: intelsat, atlantic, arabsat, sewerage, urals, reefs, mariana, relay,
# Nearest to know: i, me, discipleship, if, never, disposable, sommers, conjugative,
# Nearest to primarily: oes, iru, lutheranism, ayyavazhi, mahavira, ethnolinguistic, comprises, oesophagus,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0152 0.2365 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9623 0.2335 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9816 0.2352 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0080 0.2336 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0296 0.2337 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0006 0.2356 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9672 0.2345 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9464 0.2344 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9616 0.2330 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0145 0.2373 sec/batch
# Nearest to time: indicator, stagnated, logically, last, technologically, tailoring, memory, th,
# Nearest to as: has, walesa, in, state, important, panzers, azad, by,
# Nearest to but: victorious, possesses, confuses, canopic, lisp, infertile, enchiridion, noumena,
# Nearest to states: united, both, italy, announce, geneva, malay, anfa, abodes,
# Nearest to years: age, birth, expectancy, zero, population, male, five, rate,
# Nearest to this: rotation, gluten, judged, incarnation, the, which, airflow, suras,
# Nearest to united: states, emden, tampa, mckinley, harrison, budgets, governmental, canada,
# Nearest to b: minoru, geq, curve, laureate, popularization, edward, marquess, subgroup,
# Nearest to award: best, medal, awards, nominated, mandated, hugo, nominations, futurama,
# Nearest to ice: kamchatka, endothermic, appalachian, anisotropic, organisers, positrons, musicology, shrek,
# Nearest to pre: piracy, sitter, development, symbolize, threatens, meter, crocodile, loss,
# Nearest to cost: mainframe, screws, spread, costs, shop, mega, fuels, receipts,
# Nearest to issue: appraisal, resolve, unanimously, irregularities, tolerated, toulon, blower, directx,
# Nearest to ocean: intelsat, atlantic, arabsat, reefs, sewerage, relay, urals, inmarsat,
# Nearest to know: i, if, me, discipleship, disposable, conjugative, never, supervillain,
# Nearest to primarily: oes, lutheranism, iru, mahavira, ayyavazhi, mens, conservatory, ethnolinguistic,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9710 0.2373 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1152 0.2343 sec/batch
# ...
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8477 0.2380 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7764 0.2359 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8001 0.2339 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7713 0.2331 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8166 0.2350 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8753 0.2342 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8429 0.2334 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8569 0.2354 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8922 0.2348 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9220 0.2336 sec/batch
# Nearest to time: well, last, that, lasted, the, epd, indicator, th,
# Nearest to as: in, most, to, is, the, an, has, of,
# Nearest to but: in, be, the, to, not, is, so, riverlands,
# Nearest to states: united, usgs, italy, nation, anegada, colonies, kava, u,
# Nearest to years: age, birth, zero, expectancy, older, male, five, every,
# Nearest to this: the, which, a, to, in, rotation, just, dnow,
# Nearest to united: states, harrison, emden, mckinley, u, shag, qatar, canada,
# Nearest to b: laureate, minoru, geq, abbate, curve, observances, anabaptists, fast,
# Nearest to award: best, awards, medal, hugo, nominations, awarded, nominated, mandated,
# Nearest to ice: kamchatka, frozen, opted, sheets, broch, endothermic, polyhedral, organisers,
# Nearest to pre: piracy, sitter, gaining, interpreted, development, protozoal, hass, symbolize,
# Nearest to cost: costs, shop, mainframe, boasted, subsidy, prices, leveled, queensberry,
# Nearest to issue: resolve, blower, maladies, stated, contessa, triassic, thornton, noted,
# Nearest to ocean: intelsat, atlantic, arabsat, inmarsat, mariana, sewerage, scatter, oceans,
# Nearest to know: me, i, tell, you, we, shall, disposable, lot,
# Nearest to primarily: several, flowcharts, radically, kinds, comprises, centrosome, lutheranism, oes,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8199 0.2386 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8830 0.2342 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8594 0.2349 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8630 0.2361 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8561 0.2368 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8547 0.2359 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8446 0.2346 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8383 0.2352 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8559 0.2339 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8783 0.2360 sec/batch
# Nearest to time: well, lasted, that, last, the, periods, indicator, th,
# Nearest to as: in, most, is, to, has, an, only, the,
# Nearest to but: to, the, in, so, not, be, been, aware,
# Nearest to states: united, italy, nation, anegada, usgs, cubicle, u, kava,
# Nearest to years: age, birth, zero, five, expectancy, male, older, every,
# Nearest to this: the, which, to, a, in, just, rotation, lnot,
# Nearest to united: states, emden, harrison, u, mckinley, canada, outboard, engage,
# Nearest to b: geq, abbate, curve, minoru, laureate, fast, observances, anabaptists,
# Nearest to award: best, awards, hugo, medal, nominations, awarded, nominated, nebula,
# Nearest to ice: kamchatka, sheets, frozen, broch, opted, endothermic, polyhedral, cpm,
# Nearest to pre: piracy, gaining, sitter, development, interpreted, protozoal, with, cash,
# Nearest to cost: costs, shop, boasted, subsidy, mainframe, leveled, newark, queensberry,
# Nearest to issue: resolve, ailes, contessa, maladies, stated, laxness, thornton, blower,
# Nearest to ocean: intelsat, atlantic, arabsat, inmarsat, mariana, sewerage, oceans, relay,
# Nearest to know: i, me, you, tell, shall, we, disposable, lot,
# Nearest to primarily: several, radically, flowcharts, centrosome, lutheranism, comprises, kinds, oes,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8696 0.2363 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8257 0.2342 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8256 0.2352 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8525 0.2342 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9036 0.2366 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8566 0.2352 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9711 0.2383 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8966 0.2344 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8877 0.2348 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8057 0.2330 sec/batch
# Nearest to time: lasted, well, last, th, bragr, still, that, epd,
# Nearest to as: in, most, is, an, has, to, only, the,
# Nearest to but: to, the, be, so, riverlands, aware, in, not,
# Nearest to states: united, italy, nation, usgs, u, anegada, cubicle, anfa,
# Nearest to years: age, birth, zero, five, male, expectancy, older, female,
# Nearest to this: the, which, a, just, rotation, subshells, to, lnot,
# Nearest to united: states, harrison, u, mckinley, canada, emden, seceded, engage,
# Nearest to b: abbate, minoru, geq, laureate, observances, curve, fast, anabaptists,
# Nearest to award: best, awards, hugo, nominations, medal, awarded, nominated, nebula,
# Nearest to ice: kamchatka, sheets, broch, opted, cpm, endothermic, musicology, frozen,
# Nearest to pre: piracy, gaining, sitter, protozoal, development, remembrance, crocodile, past,
# Nearest to cost: costs, shop, boasted, subsidy, mainframe, labors, leveled, queensberry,
# Nearest to issue: resolve, ailes, contessa, stated, blower, thornton, toulon, laxness,
# Nearest to ocean: intelsat, arabsat, atlantic, inmarsat, mariana, sewerage, relay, isps,
# Nearest to know: me, i, you, tell, shall, disposable, we, lot,
# Nearest to primarily: several, radically, comprises, lutheranism, centrosome, honshu, flowcharts, kinds,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8292 0.2368 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8229 0.2345 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8267 0.2344 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8783 0.2359 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8316 0.2345 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8783 0.2358 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8664 0.1774 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8500 0.2358 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8223 0.2344 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8660 0.2348 sec/batch
# Nearest to time: lasted, last, well, that, still, bragr, the, th,
# Nearest to as: in, most, to, is, the, an, of, and,
# Nearest to but: to, not, the, in, be, is, he, eked,
# Nearest to states: united, usgs, italy, anegada, nation, u, cubicle, colonies,
# Nearest to years: age, birth, zero, five, male, expectancy, older, every,
# Nearest to this: the, which, to, in, a, by, is, subshells,
# Nearest to united: states, u, harrison, mckinley, canada, engage, seceded, qatar,
# Nearest to b: abbate, laureate, marquess, minoru, observances, hardwicke, diplomat, fast,
# Nearest to award: best, awards, hugo, medal, nominations, nominated, awarded, affirms,
# Nearest to ice: kamchatka, sheets, broch, cpm, opted, endothermic, frozen, musicology,
# Nearest to pre: piracy, gaining, sitter, interpreted, symbolize, development, protozoal, remembrance,
# Nearest to cost: costs, subsidy, shop, mainframe, boasted, labors, screws, queensberry,
# Nearest to issue: resolve, contessa, ailes, stated, blower, backfire, hatching, thornton,
# Nearest to ocean: intelsat, arabsat, atlantic, inmarsat, mariana, sewerage, reefs, relay,
# Nearest to know: me, i, tell, you, we, shall, disposable, never,
# Nearest to primarily: several, radically, flowcharts, comprises, lutheranism, syncretic, centrosome, kinds,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7656 0.2372 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8227 0.2346 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7627 0.2354 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8897 0.2360 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8229 0.2329 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8335 0.2348 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8535 0.2361 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7259 0.2350 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8361 0.2351 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7691 0.2348 sec/batch
# Nearest to time: that, lasted, well, last, epd, the, not, th,
# Nearest to as: in, most, to, is, and, the, an, a,
# Nearest to but: to, be, in, is, not, so, the, that,
# Nearest to states: united, usgs, anegada, nation, u, italy, cubicle, kava,
# Nearest to years: age, birth, zero, five, male, expectancy, live, two,
# Nearest to this: the, which, a, to, is, in, that, just,
# Nearest to united: states, u, canada, harrison, qatar, engage, emden, tutuila,
# Nearest to b: abbate, geq, minoru, curve, fast, anabaptists, topspinner, laureate,
# Nearest to award: best, awards, hugo, medal, nominations, awarded, nominated, prizes,
# Nearest to ice: kamchatka, broch, sheets, opted, frozen, endothermic, cpm, musicology,
# Nearest to pre: piracy, gaining, protozoal, interpreted, development, remembrance, neolithic, cash,
# Nearest to cost: costs, subsidy, shop, labors, mainframe, boasted, screws, leveled,
# Nearest to issue: resolve, ailes, contessa, hatching, stated, noted, blower, backfire,
# Nearest to ocean: intelsat, arabsat, atlantic, inmarsat, mariana, sewerage, relay, oceans,
# Nearest to know: me, i, you, tell, we, shall, lot, staden,
# Nearest to primarily: several, flowcharts, radically, lutheranism, other, for, produced, centrosome,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7878 0.2367 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8249 0.2350 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8685 0.2344 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7924 0.2352 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8436 0.2358 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9162 0.2343 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8084 0.2345 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8164 0.2329 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8448 0.2351 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8284 0.2346 sec/batch
# Nearest to time: well, that, lasted, epd, the, last, not, pitching,
# Nearest to as: in, to, most, is, the, only, of, a,
# Nearest to but: to, not, be, so, the, in, is, even,
# Nearest to states: united, italy, usgs, u, nation, anegada, cubicle, kava,
# Nearest to years: age, birth, five, expectancy, male, zero, live, female,
# Nearest to this: the, which, a, in, to, is, just, by,
# Nearest to united: states, u, canada, harrison, qatar, emden, engage, countries,
# Nearest to b: abbate, laureate, minoru, observances, hardwicke, marquess, geq, anabaptists,
# Nearest to award: best, awards, hugo, medal, nominations, awarded, nominated, mandated,
# Nearest to ice: kamchatka, broch, opted, sheets, frozen, cpm, endothermic, musicology,
# Nearest to pre: piracy, gaining, development, interpreted, protozoal, remembrance, hass, neolithic,
# Nearest to cost: costs, subsidy, shop, boasted, labors, leveled, screws, prices,
# Nearest to issue: resolve, contessa, ailes, noted, hatching, blower, stated, unanimously,
# Nearest to ocean: intelsat, arabsat, atlantic, inmarsat, mariana, sewerage, relay, oceans,
# Nearest to know: me, i, we, you, tell, shall, lot, libro,
# Nearest to primarily: several, flowcharts, radically, lutheranism, produced, other, comprises, syncretic,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8479 0.2375 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8516 0.2353 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8379 0.2359 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8274 0.2356 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8568 0.2349 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8364 0.2383 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8475 0.2332 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8318 0.2364 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8052 0.2366 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8255 0.2339 sec/batch
# Nearest to time: well, that, lasted, the, not, epd, at, last,
# Nearest to as: in, most, is, of, to, and, an, the,
# Nearest to but: not, be, the, is, to, so, in, that,
# Nearest to states: united, italy, u, nation, usgs, cubicle, anegada, colonies,
# Nearest to years: age, birth, five, zero, expectancy, male, live, older,
# Nearest to this: the, which, to, in, a, is, by, for,
# Nearest to united: states, u, canada, qatar, harrison, mckinley, emden, countries,
# Nearest to b: abbate, minoru, observances, geq, fast, laureate, anabaptists, curve,
# Nearest to award: best, awards, hugo, medal, nominations, awarded, nominated, prizes,
# Nearest to ice: kamchatka, broch, sheets, opted, frozen, cpm, musicology, polyhedral,
# Nearest to pre: piracy, gaining, development, early, sitter, crocodile, interpreted, loss,
# Nearest to cost: costs, subsidy, shop, mainframe, labors, screws, leveled, boasted,
# Nearest to issue: resolve, ailes, contessa, blower, stated, unanimously, directx, hatching,
# Nearest to ocean: intelsat, atlantic, arabsat, inmarsat, mariana, sewerage, relay, isps,
# Nearest to know: me, i, you, we, tell, shall, if, lot,
# Nearest to primarily: several, radically, flowcharts, produced, lutheranism, and, centrosome, comprises,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8699 0.2381 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8660 0.2364 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9131 0.2367 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8993 0.2347 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8970 0.2360 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7926 0.2364 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7872 0.2338 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8336 0.2334 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7945 0.2357 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8687 0.2349 sec/batch
# Nearest to time: well, lasted, epd, the, last, at, not, th,
# Nearest to as: in, most, is, to, of, the, a, an,
# Nearest to but: so, not, be, to, the, both, that, been,
# Nearest to states: united, italy, usgs, u, cubicle, anegada, nation, colonies,
# Nearest to years: age, birth, zero, five, male, expectancy, live, female,
# Nearest to this: a, which, the, is, to, in, just, by,
# Nearest to united: states, u, canada, harrison, withdrawn, japan, qatar, emden,
# Nearest to b: abbate, minoru, laureate, observances, marquess, hardwicke, fast, edward,
# Nearest to award: best, awards, hugo, medal, nominations, awarded, nominated, affirms,
# Nearest to ice: kamchatka, broch, sheets, opted, cpm, frozen, musicology, organisers,
# Nearest to pre: piracy, gaining, interpreted, hass, sitter, development, remembrance, early,
# Nearest to cost: costs, subsidy, mainframe, labors, shop, screws, boasted, leveled,
# Nearest to issue: resolve, ailes, contessa, blower, unanimously, hatching, stated, thornton,
# Nearest to ocean: intelsat, arabsat, atlantic, inmarsat, mariana, relay, sewerage, scatter,
# Nearest to know: me, i, you, tell, we, shall, don, sure,
# Nearest to primarily: several, radically, flowcharts, lutheranism, other, comprises, centrosome, kinds,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8239 0.2397 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8462 0.2370 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
